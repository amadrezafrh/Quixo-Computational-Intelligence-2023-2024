# %%
import os
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3'

from stable_baselines3.common.env_checker import check_env
from game import Game, Move, Player
from utils import play_game, evaluate
from players import RandomPlayer, ValuePlayer, DeterministicPlayer, PPOPlayer
from models import ValueClass, PPOWrapper, DQNWrapper, A2CWrapper
from envs import QuixoEnv

# %%
rplayer = RandomPlayer()
eplayer = ValuePlayer()
play_game(eplayer, rplayer)
# Out:
# Winner: Player 0

# %%
vd = ValueClass(rplayer, eplayer)
vd.train(steps=100)
vd.save()
vd.load('./models/model.json')
# Out:
#   0%|          | 0/100 [00:00<?, ?it/s]
# Value dictionary exists
# value dictionary loaded

# %%
env = QuixoEnv(player=0)
try:
    check_env(env)
    print('env check: TRUE')
except:
    print('env check: FALSE')
env.experiment()
# Out:
# env check: TRUE
# episode length: 18
# total reward: 6
# winner: player 1

# %%
ppo = PPOWrapper()
ppo.train(ts=3000, callbacks=1000)
# Out:
# Logging to ./logs/ppo/./quixo-ppo-0_1
# Output()
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 34       |
# |    ep_rew_mean     | -60.9    |
# | time/              |          |
# |    fps             | 334      |
# |    iterations      | 1        |
# |    time_elapsed    | 6        |
# |    total_timesteps | 2048     |
# ---------------------------------
# Logging to ./logs/ppo/./quixo-ppo-1_1
# Output()
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 37.6     |
# |    ep_rew_mean     | -92.4    |
# | time/              |          |
# |    fps             | 351      |
# |    iterations      | 1        |
# |    time_elapsed    | 5        |
# |    total_timesteps | 2048     |
# ---------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 37.1        |
# |    ep_rew_mean          | -82         |
# | time/                   |             |
# |    fps                  | 304         |
# |    iterations           | 2           |
# |    time_elapsed         | 13          |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.010580217 |
# |    clip_fraction        | 0.0782      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.78       |
# |    explained_variance   | -0.00228    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.68e+03    |
# |    n_updates            | 10          |
# |    policy_gradient_loss | -0.0384     |
# |    value_loss           | 3.35e+03    |
# -----------------------------------------

# %%
dqn = DQNWrapper()
dqn.train(ts=3000, callbacks=1000)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[6], line 2
#       1 dqn = DQNWrapper()
# ----> 2 dqn.train(ts=3000, callbacks=1000)
#
# File ~/Desktop/quixo/models.py:217, in DQNWrapper.train(self, net_arch, policy, verbose, progress_bar, ts, callbacks)
#     215 env = QuixoEnv(player=player)
#     216 with open(os.devnull, "w") as f, contextlib.redirect_stdout(f):
# --> 217     model = DQN(policy, env, policy_kwargs=policy_kwargs, verbose=verbose, tensorboard_log="./logs/dqn")
#     218 model.learn(total_timesteps=ts, progress_bar=progress_bar, callback=checkpoint_callback, tb_log_name=f"./quixo-dqn-{player}")
#     219 model.save(f"{self.models_dir}/quixo-dqn-{player}")
#
# File ~/.local/lib/python3.10/site-packages/stable_baselines3/dqn/dqn.py:137, in DQN.__init__(self, policy, env, learning_rate, buffer_size, learning_starts, batch_size, tau, gamma, train_freq, gradient_steps, replay_buffer_class, replay_buffer_kwargs, optimize_memory_usage, target_update_interval, exploration_fraction, exploration_initial_eps, exploration_final_eps, max_grad_norm, tensorboard_log, policy_kwargs, verbose, seed, device, _init_setup_model)
#     134 self.q_net, self.q_net_target = None, None
#     136 if _init_setup_model:
# --> 137     self._setup_model()
#
# File ~/.local/lib/python3.10/site-packages/stable_baselines3/dqn/dqn.py:140, in DQN._setup_model(self)
#     139 def _setup_model(self) -> None:
# --> 140     super()._setup_model()
#     141     self._create_aliases()
#     142     # Copy running stats, see GH issue #996
#
# File ~/.local/lib/python3.10/site-packages/stable_baselines3/common/off_policy_algorithm.py:215, in OffPolicyAlgorithm._setup_model(self)
#     204 if self.replay_buffer is None:
#     205     self.replay_buffer = self.replay_buffer_class(
#     206         self.buffer_size,
#     207         self.observation_space,
#    (...)
#     212         **self.replay_buffer_kwargs,
#     213     )
# --> 215 self.policy = self.policy_class(  # pytype:disable=not-instantiable
#     216     self.observation_space,
#     217     self.action_space,
#     218     self.lr_schedule,
#     219     **self.policy_kwargs,  # pytype:disable=not-instantiable
#     220 )
#     221 self.policy = self.policy.to(self.device)
#     223 # Convert train freq parameter to TrainFreq object
#
# TypeError: DQNPolicy.__init__() got an unexpected keyword argument 'pi'

# %%
a2c = A2CWrapper()
a2c.train(ts=3000, callbacks=1000)

# %%
eplayer = DeterministicPlayer()
opponent = RandomPlayer()
evaluate(eplayer,eplayer,opponent, enum=100)
# Out:
# WIN RATIO -- PLAYING SECOND:   0.89
# WIN RATIO -- PLAYING FIRST:    0.83
# TOTAL WIN RATIO:               0.86

# %%
opponent = RandomPlayer()
with open(os.devnull, "w") as f, contextlib.redirect_stdout(f):
    env0 = QuixoEnv(player=0)
    env1 = QuixoEnv(player=1)
    eplayer_first = PPOPlayer(env0)
    eplayer_second = PPOPlayer(env1)
    
evaluate(eplayer_first, eplayer_second, opponent, enum=100)
# Out:
# WIN RATIO -- PLAYING SECOND:   0.98
# WIN RATIO -- PLAYING FIRST:    0.92
# TOTAL WIN RATIO:               0.95
